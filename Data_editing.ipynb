# %%
import pandas as pd

data = pd.read_csv('data.csv')

data
# Out:
#                                            Issue Title  \
# 0    Module '"@egoist/tipc/renderer"' has no export...
# 1                        Issue Template Not works well
# 2                                                 blur
# 3    Node Automated Deployer should generate a rand...
# 4               typo: redis expose port should be 6379
# ..                                                 ...
# 157                   How to Support Time-range Search
# 158        Crashing (SEGV) when using `JSON.stringify`
# 159  Confusing Returnings of Server Side Rendering API
# 160  📄 PNPM should also install `@master/style` man...
# 161  🐞 Newline breaks the layout of interactive sty...
#
#                                             Issue Body
# 0    it seems tipc does not support "Calling render...
# 1    When I try to create a new issue for Chaos Mes...
# 2    ### Tag\r\n\r\nCollectible\r\n\r\n### Project ...
# 3    This issue related to https://github.com/RSS3-...
# ...

# %%
# Bug
